# %%
pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.9/dist-packages (2.70.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.17.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.12)

# %%
import json

# %% [markdown]
# Test this out Only

# %%
from googleapiclient.discovery import build
my_api_key = "AIzaSyCWJ9-zXoQr53YWxT9hHoGX4DGRsWNx_kQ"
my_cse_id = "f048ca8e92d064c34"

# Load the JSON file containing questions
with open('/content/tables.json') as f:
    questions = json.load(f)

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res

i=0
for i in range(len(questions)):

  result = google_search(questions[i]['subquestion'], my_api_key, my_cse_id)
  for values in (result['items']):
   print(values['snippet'])
   print("\n")

   print(values['htmlSnippet'])
   print("\n")
   print("\n")
   print("\n")
   
# print(result.values())
# Out:
# Billboard Hot 100. All Charts · All Charts. Menu. Hot 100 · Billboard 200 · Global 200 · View All ... Weeks on chart ... What He Didn't Do. Carly Pearce.
#
#
# <b>Billboard Hot 100</b>. All <b>Charts</b> &middot; All <b>Charts</b>. Menu. <b>Hot 100</b> &middot; <b>Billboard</b> 200 &middot; Global 200 &middot; View All ... Weeks on <b>chart</b> ... What He Didn&#39;t <b>Do</b>. Carly Pearce.
#
#
#
#
#
#
# The Billboard Hot 100 is the music industry standard record chart in the United States for songs, published weekly by Billboard magazine. Chart rankings are ...
#
#
# The <b>Billboard Hot 100 is</b> the music industry standard record <b>chart</b> in the United States for <b>songs</b>, published weekly by <b>Billboard</b> magazine. <b>Chart</b> rankings are&nbsp;...
#
#
#
#
#
#
# Oct 31, 2022 ... 1 on Billboard 200 Chart With Biggest Week for an Album… 10/31/2022 ... “Look What You Made Me Do,” three weeks, beginning Sept. 16, 2017
#
#
# Oct 31, 2022 <b>...</b> 1 on <b>Billboard</b> 200 <b>Chart</b> With Biggest Week for an Album… 10/31/2022 ... “Look What You <b>Made</b> Me <b>Do</b>,” three weeks, beginning Sept. 16, 2017
#
#
#
#
#
#
# see charts legends. Billboard Hot 100 ... CHARTs. Billboard Global Excl. US. Lazy loaded image ... Here's When Suga's Debut Solo Album 'Day-Day' Is Dropping.
#
#
# see <b>charts</b> legends. <b>Billboard Hot 100</b> ... <b>CHARTs</b>. <b>Billboard</b> Global Excl. US. Lazy loaded image ... Here&#39;s When Suga&#39;s Debut Solo Album &#39;Day-Day&#39; <b>Is</b> Dropping.
#
#
#
#
#
#
# Features · The 100 Best Taylor Swift Songs: Staff Picks · Is TikTok Actually Creating More One-Hit Wonders? · Can This Lost Operatic Masterpiece Be Staged Without ...
#
#
# Features &middot; The <b>100 Best</b> Taylor Swift <b>Songs</b>: Staff Picks &middot; <b>Is</b> TikTok Actually <b>Creating</b> More One-Hit Wonders? &middot; Can This Lost Operatic Masterpiece Be Staged Without&nbsp;...
#
#
#
#
#
#
# Aug 8, 2022 ... Pop singer-songwriter and 'American Idol' alum Jax makes her first visit to the Billboard Hot 100 chart thanks to "Victoria's Secret."
#
#
# Aug 8, 2022 <b>...</b> Pop singer-songwriter and &#39;American Idol&#39; alum Jax <b>makes</b> her first visit to the <b>Billboard Hot 100 chart</b> thanks to &quot;Victoria&#39;s Secret.&quot;
#
#
#
#
#
#
# Jun 1, 2022 ... How high will it have to get to be the U.K. singer-songwriter's biggest ... (Billboard did not introduce its Alternative Airplay chart until ...
#
#
# Jun 1, 2022 <b>...</b> How high will it have to <b>get</b> to be the U.K. singer-songwriter&#39;s biggest ... (<b>Billboard did</b> not introduce its Alternative Airplay <b>chart</b> until&nbsp;...
#
#
#
#
#
#
# Oct 31, 2022 ... Taylor Swift makes history as the first artist to monopolize the entire top 10 in a single week, and passes Madonna for the most top 10 hits ...
#
#
# Oct 31, 2022 <b>...</b> Taylor Swift <b>makes</b> history as the first artist to monopolize the entire <b>top</b> 10 in a single week, and passes Madonna for the most <b>top</b> 10 <b>hits</b>&nbsp;...
#
#
#
#
#
#
# Chart History · Billboard Hot 100 · Billboard Hot 100 · All I Want For Christmas Is You · We Belong Together · Always Be My Baby · Hero · Dreamlover · One Sweet Day.
#
#
# <b>Chart</b> History &middot; <b>Billboard Hot 100</b> &middot; <b>Billboard Hot 100</b> &middot; All I Want For Christmas <b>Is</b> You &middot; We Belong Together &middot; Always Be My Baby &middot; Hero &middot; Dreamlover &middot; One Sweet Day.
#
#
#
#
#
#
# Apr 11, 2016 ... 1 on the Radio Songs airplay chart, the track was not released as ... (The latter track was stuck behind Manfred Mann's “Do Wah Diddy Diddy.
#
#
# Apr 11, 2016 <b>...</b> 1 on the Radio <b>Songs</b> airplay <b>chart</b>, the track <b>was</b> not released as ... (The latter track <b>was</b> stuck behind Manfred Mann&#39;s “<b>Do</b> Wah Diddy Diddy.
#
#
#
#
#
#
# A new chart is compiled and released on line to the public by Billboard website on Tuesdays but post-dated to the following Saturday when the printed ...
#
#
# <b>A</b> new <b>chart is</b> compiled and released on line to the public by <b>Billboard</b> website on Tuesdays <b>but</b> post-dated to the following Saturday <b>when</b> the printed&nbsp;...
#
#
#
#
#
#
# Jun 1, 2022 ... Kate Bush's "Running Up That Hill" is now pulling millions of streams a day -- but will it vault the song past its original Hot 100 peak?
#
#
# Jun 1, 2022 <b>...</b> Kate Bush&#39;s &quot;Running Up <b>That</b> Hill&quot; <b>is</b> now pulling millions of streams <b>a</b> day -- <b>but will</b> it vault the song past <b>its</b> original Hot 100 <b>peak</b>?
#
#
#
#
#
#
# The Billboard 200 is a record chart ranking the 200 most popular music albums and EPs in the United States. It is published weekly by Billboard magazine and ...
#
#
# The <b>Billboard</b> 200 <b>is a</b> record <b>chart</b> ranking the 200 most popular music albums and EPs in the United States. It <b>is</b> published weekly by <b>Billboard</b> magazine and&nbsp;...
#
#
#
#
#
#
# Nov 10, 2021 ... Artist charts are a reflection of who is at the top of their game based on streams ... peak positions, and streaks from the expanded view.
#
#
# Nov 10, 2021 <b>...</b> Artist <b>charts</b> are <b>a</b> reflection of who <b>is</b> at the <b>top</b> of <b>their</b> game based on streams ... <b>peak positions</b>, and streaks from the expanded <b>view</b>.
#
#
#
#
#
#
# Music Charts, News, Photos &amp; Video. ... Video. View All ... Why Apple's Classical Streaming Service Is a Good Sign for the Music Subscription Business.
#
#
# Music <b>Charts</b>, News, Photos &amp;amp; Video. ... Video. <b>View</b> All ... Why Apple&#39;s Classical Streaming Service <b>Is a</b> Good Sign for the Music Subscription Business.
#
#
#
#
#
#
# *Isobars are the solid lines (they are NOT height contours) *Unlike the upper air charts, this chart is not at a constant pressure level for each ...
#
#
# *Isobars are the solid lines (they are NOT <b>height</b> contours) *Unlike the upper air <b>charts</b>, this <b>chart is</b> not at <b>a</b> constant pressure level for each&nbsp;...
#
#
#
#
#
#
# May 27, 2022 ... An expansion is the period from a trough to its subsequent peak or ... This chart book documents the 2009-2020 economic expansion and will ...
#
#
# May 27, 2022 <b>...</b> An expansion <b>is</b> the period from <b>a</b> trough to <b>its</b> subsequent <b>peak</b> or ... This <b>chart</b> book documents the 2009-2020 economic expansion and <b>will</b>&nbsp;...
#
#
#
#
#
#
# Customizing the bars on a Gantt Chart view is often the first thing a project manager does to create clarity in a ... Change the height of Gantt bars.
#
#
# Customizing the bars on <b>a</b> Gantt <b>Chart view is</b> often the first thing <b>a</b> project manager <b>does</b> to create clarity in <b>a</b> ... Change the <b>height</b> of Gantt bars.
#
#
#
#
#
#
# Oct 1, 2012 ... Growth charts are the best tool to assess a child's growth and overall health. Children's height and weight usually, though not always, ...
#
#
# Oct 1, 2012 <b>...</b> Growth <b>charts</b> are the best tool to assess <b>a</b> child&#39;s growth and overall health. Children&#39;s <b>height</b> and weight usually, <b>though</b> not always,&nbsp;...
#
#
#
#
#
#
# Dec 7, 2022 ... A column chart is a vertical bar chart rendered in the browser using ... var options = { width: 600, height: 400, legend: { position: 'top', ...
#
#
# Dec 7, 2022 <b>...</b> <b>A</b> column <b>chart is a</b> vertical bar <b>chart</b> rendered in the browser using ... var options = { width: 600, <b>height</b>: 400, legend: { <b>position</b>: &#39;<b>top</b>&#39;,&nbsp;...
#
#
#
#
#
#
# Explore the music you love. Discover songs, lyrics, and artists on Shazam. ... Shazam will name your song in seconds. Download the app ...
#
#
# Explore the music you love. Discover <b>songs</b>, lyrics, and artists on Shazam. ... Shazam will <b>name</b> your <b>song</b> in seconds. Download the app&nbsp;...
#
#
#
#
#
#
# Tip: Google Assistant can only identify songs that have lyrics. Use the Google app to name a song. On your Android phone or tablet, open the Google app Google ...
#
#
# Tip: Google Assistant can only identify <b>songs</b> that have lyrics. Use the Google app to <b>name</b> a <b>song</b>. On your Android phone or tablet, open the Google app Google&nbsp;...
#
#
#
#
#
#
# Jan 7, 2012 ... Well, here are some of the best music recognition services that can help you discover song names without having to know the lyrics.
#
#
# Jan 7, 2012 <b>...</b> Well, here are some of the best music recognition services that can help you discover <b>song names</b> without having to know the lyrics.
#
#
#
#
#
#
# The Song of Names is a 2019 drama film directed by François Girard. ... An adaptation of the novel of the same name by Norman Lebrecht, it stars Tim Roth and ...
#
#
# The <b>Song</b> of <b>Names</b> is a 2019 drama film directed by François Girard. ... An adaptation of the novel of the same <b>name</b> by Norman Lebrecht, it stars Tim Roth and&nbsp;...
#
#
#
#
#
#
# What's the Name of That Song? is a 2004 Sesame Street direct-to-video special in which Super Grover must find one song that the whole world can sing ...
#
#
# What&#39;s the <b>Name</b> of That <b>Song</b>? is a 2004 Sesame Street direct-to-video special in which Super Grover must find one <b>song</b> that the whole world can sing&nbsp;...
#
#
#
#
#
#
# Dec 30, 2018 ... 5 surefire ways to find the name of that song · 1. Shazam · 2. SoundHound · 3. Google Sound Search · 4. Ask Siri or Alexa · 5. Genius or Google ...
#
#
# Dec 30, 2018 <b>...</b> 5 surefire ways to find the <b>name</b> of that <b>song</b> &middot; 1. Shazam &middot; 2. SoundHound &middot; 3. Google Sound Search &middot; 4. Ask Siri or Alexa &middot; 5. Genius or Google&nbsp;...
#
#
#
#
#
#
# "What's the Name of That Song?" is a Sesame Street song that asks the question, "what's the name of that song?" Typically performed by an ensemble, ...
#
#
# &quot;What&#39;s the <b>Name</b> of That <b>Song</b>?&quot; is a Sesame Street <b>song</b> that asks the question, &quot;what&#39;s the <b>name</b> of that <b>song</b>?&quot; Typically performed by an ensemble,&nbsp;...
#
#
#
#
#
#
# Sesame Street: What's the Name of That Song?: Directed by Victor DiNapoli. With Pam Arciero, Wayne Brady, Fran Brill, Kevin Clash.
#
#
# Sesame Street: What&#39;s the <b>Name</b> of That <b>Song</b>?: Directed by Victor DiNapoli. With Pam Arciero, Wayne Brady, Fran Brill, Kevin Clash.
#
#
#
#
#
#
# Shazam will identify any song in seconds. ... It actually put a name to a song I had been wishing for the possibility to have on my playlist and I found it ...
#
#
# Shazam will identify any <b>song</b> in seconds. ... It actually put a <b>name</b> to a <b>song</b> I had been wishing for the possibility to have on my playlist and I found it&nbsp;...
#
#
#
#
#
#
# The Song of Names ... Martin Simmonds (Tim Roth) has been haunted throughout his life by the mysterious disappearance.
#
#
# The <b>Song</b> of <b>Names</b> ... Martin Simmonds (Tim Roth) has been haunted throughout his life by the mysterious disappearance.
#
#
#
#
#
#
# "Suddenly Last Summer" is a new wave song by American new wave band the Motels, released as the lead single from their fourth album, Little Robbers (1983).
#
#
# &quot;Suddenly <b>Last Summer</b>&quot; is a new wave <b>song</b> by American new wave band the Motels, <b>released</b> as the lead single from their fourth album, Little Robbers (1983).
#
#
#
#
#
#
# Jan 28, 2021 ... “Finishing engineering this year, production starts next year. Aiming to have release candidate design drivable late summer,” the Tesla CEO ...
#
#
# Jan 28, 2021 <b>...</b> “Finishing engineering this <b>year</b>, production starts next <b>year</b>. Aiming to have <b>release</b> candidate design drivable <b>late summer</b>,” the Tesla CEO&nbsp;...
#
#
#
#
#
#
# The film centers on four young friends who are stalked by a hook-wielding killer one year after covering up a car accident in which they supposedly killed a man ...
#
#
# The film centers on four young friends who are stalked by a hook-wielding killer one <b>year</b> after covering up a car accident in which they supposedly killed a man&nbsp;...
#
#
#
#
#
#
# May 17, 2012 ... She claimed a top 40 hit every year from 1976 and 1984. And, between 1976 and the end of 1982, she had more top 10 hits — 12 — than any other ...
#
#
# May 17, 2012 <b>...</b> She claimed a top 40 <b>hit</b> every <b>year</b> from 1976 and 1984. And, between 1976 and the <b>end of</b> 1982, she had more top 10 <b>hits</b> — 12 — than any other&nbsp;...
#
#
#
#
#
#
# Jun 25, 2022 ... Summer 1969 was already under way when Stone handed in this heavenly soul ballad to Epic Records, which was wary of releasing a summer song in ...
#
#
# Jun 25, 2022 <b>...</b> <b>Summer</b> 1969 was already under way <b>when</b> Stone handed in this heavenly soul ballad to Epic Records, which was wary of <b>releasing</b> a <b>summer song</b> in&nbsp;...
#
#
#
#
#
#
# Aug 30, 2021 ... Every year, everyone wonders which song will be crowned the "song of the summer. ... "One of These Nights" was released on June 10, 1975.
#
#
# Aug 30, 2021 <b>...</b> Every <b>year</b>, everyone wonders which <b>song</b> will be crowned the &quot;<b>song</b> of the <b>summer</b>. ... &quot;One of These Nights&quot; was <b>released</b> on June 10, 1975.
#
#
#
#
#
#
# Jun 18, 2020 ... Still, the fact that reruns of a 15-year-old animated series are doing so well is pretty incredible, particularly given the lack of any major ...
#
#
# Jun 18, 2020 <b>...</b> Still, the fact that reruns of a 15-<b>year</b>-old animated series are doing so well is pretty incredible, particularly given the lack of any major&nbsp;...
#
#
#
#
#
#
# Students who did not receive PEBT for this or last school year will be mailed a card with Summer PEBT benefits already loaded onto it.
#
#
# Students who did not receive PEBT for this or <b>last</b> school <b>year</b> will be mailed a card with <b>Summer</b> PEBT benefits already loaded onto it.
#
#
#
#
#
#
# In the final battle, Ben is swinging the fisherman's hook at Julie but hitting nothing but air. · When the body is found in the trunk, its throat is clearly ...
#
#
# In the final battle, Ben is swinging the fisherman&#39;s hook at Julie but <b>hitting</b> nothing but air. &middot; <b>When</b> the body is found in the trunk, its throat is clearly&nbsp;...
#
#
#
#
#
#
# Aug 31, 2022 ... It's one of the most retro tracks to make it onto Spotify's Songs of Summer list—37 years after its release. Fans born after the song was ...
#
#
# Aug 31, 2022 <b>...</b> It&#39;s one of the most retro tracks to make it onto Spotify&#39;s Songs of <b>Summer</b> list—37 <b>years</b> after its <b>release</b>. Fans born after the <b>song</b> was&nbsp;...
#
#
#
#
#
#
# May 25, 1787, freshly spread dirt covered the cobblestone street in front of ... "whether any middle ground can be taken which will at once support a due ...
#
#
# <b>May</b> 25, 1787, freshly spread dirt covered the cobblestone street <b>in</b> front of ... &quot;<b>whether any</b> middle ground <b>can</b> be taken which <b>will</b> at once <b>support</b> a due&nbsp;...
#
#
#
#
#
#
# Every milestone was linked to meeting this deadline. For most ventures, however, significant events—not dates—should determine milestones. The only hard dates ...
#
#
# Every <b>milestone</b> was <b>linked</b> to meeting this deadline. For most ventures, however, <b>significant events</b>—not dates—should <b>determine milestones</b>. The only hard dates&nbsp;...
#
#
#
#
#
#
# Feb 8, 2022 ... EnlargeDownload Link Citation: An act to enforce the fifteenth amendment to the Constitution of the United States and for other purposes, ...
#
#
# Feb 8, 2022 <b>...</b> EnlargeDownload Link Citation: <b>An</b> act to enforce the fifteenth amendment to the Constitution of the United States and for other purposes,&nbsp;...
#
#
#
#
#
#
# Sep 1, 2017 ... And it's really no wonder: Video games have been around for ... The video game industry had a few notable milestones in the late 1970s and ...
#
#
# Sep 1, 2017 <b>...</b> And it&#39;s really <b>no</b> wonder: Video games have been around for ... The video game industry had a few <b>notable milestones in</b> the late 1970s and&nbsp;...
#
#
#
#
#
#
# Sep 11, 2018 ... The idea for the first Food Stamp Program (FSP) is credited to various people, most notably Secretary of Agriculture Henry Wallace and the ...
#
#
# Sep 11, 2018 <b>...</b> The idea for the first Food Stamp Program (FSP) is credited to various people, most <b>notably</b> Secretary of Agriculture Henry Wallace and the&nbsp;...
#
#
#
#
#
#
# Sam Walton was a man with visionary leadership, and our business is a result of that. Since the first Walmart opened in 1962 in Rogers, Arkansas, ...
#
#
# Sam Walton was a man with visionary leadership, and our business is a result of that. Since the first Walmart opened <b>in</b> 1962 <b>in</b> Rogers, Arkansas,&nbsp;...
#
#
#
#
#
#
# Here is a list of terms associated with PERT charts: Nodes are visual representations of milestones or events within the project. They are drawn as either ...
#
#
# Here is a list of terms <b>associated</b> with PERT charts: Nodes are visual representations of <b>milestones</b> or <b>events</b> within the project. <b>They</b> are drawn as <b>either</b>&nbsp;...
#
#
#
#
#
#
# “Milestones in the History of U.S. Foreign Relations” has been retired and is no ... Americans hoped for democratic reforms that would solidify the existing ...
#
#
# “<b>Milestones in</b> the <b>History</b> of U.S. Foreign Relations” has been retired and is <b>no</b> ... Americans hoped for democratic reforms that <b>would</b> solidify the existing&nbsp;...
#
#
#
#
#
#
# Jan 2, 2020 ... Big Macs. Chicken McNuggets. The legendary Egg McMuffin. It all started with a hot dog and a drive-through barbecue restaurant.
#
#
# Jan 2, 2020 <b>...</b> <b>Big</b> Macs. Chicken McNuggets. The legendary Egg McMuffin. It all started with a hot dog and a drive-through barbecue restaurant.
#
#
#
#
#
#
# Aug 1, 2022 ... Here are some of our milestones along the way: ... To show our support for diversity in college admissions and giving students of color an ...
#
#
# Aug 1, 2022 <b>...</b> Here are <b>some</b> of our <b>milestones</b> along the way: ... To show our <b>support</b> for diversity <b>in</b> college admissions and giving students of color <b>an</b>&nbsp;...
#
#
#
#
#
#
# But when people ask whether it is possible to prove that Jesus of Nazareth actually existed, as John P. Meier pointed out decades ago, “The implication is ...
#
#
# But when people ask whether it is possible to <b>prove</b> that Jesus of Nazareth actually <b>existed</b>, as John P. Meier pointed out decades <b>ago</b>, “The implication is&nbsp;...
#
#
#
#
#
#
# Jun 29, 2022 ... While scientists have long hypothesized that early humans started using ... Until recently, though, only scant evidence existed to support ...
#
#
# Jun 29, 2022 <b>...</b> While scientists have long hypothesized that <b>early</b> humans <b>started</b> using ... Until recently, though, only scant <b>evidence existed</b> to support&nbsp;...
#
#
#
#
#
#
# The committee found that the evidence confirmed the Senate committee's report that AMLASH himself envisioned assassination as an essential first step in any ...
#
#
# The committee found that the <b>evidence confirmed</b> the Senate committee&#39;s report that AMLASH himself envisioned assassination as an essential <b>first</b> step in any&nbsp;...
#
#
#
#
#
#
# Mar 16, 2008 ... The Law & Order franchise, for example, appears on television several ... Our goal was to determine if there was any empirical evidence ...
#
#
# Mar 16, 2008 <b>...</b> The Law &amp; Order <b>franchise</b>, for example, appears on television several ... Our goal was to <b>determine</b> if there was any empirical <b>evidence</b>&nbsp;...
#
#
#
#
#
#
# To those suspicious of the convention, the curtain of secrecy only served to confirm their anxieties. Luther Martin of Maryland later charged that the ...
#
#
# To those suspicious of the convention, the curtain of secrecy only served to <b>confirm</b> their anxieties. Luther Martin of Maryland <b>later</b> charged that the&nbsp;...
#
#
#
#
#
#
# A business corporation may be formed by filing a Certificate of ... The New York State Tax Law requires a corporation to file franchise tax reports and pay ...
#
#
# A business corporation may be <b>formed</b> by filing a Certificate of ... The New York State Tax Law requires a corporation to file <b>franchise</b> tax reports and pay&nbsp;...
#
#
#
#
#
#
# Nov 7, 2022 ... If you have a past due, legally enforceable California income tax ... is not past due or not legally enforceable, you must send evidence to ...
#
#
# Nov 7, 2022 <b>...</b> If you have a <b>past</b> due, legally enforceable California income tax ... is not <b>past</b> due or not legally enforceable, you must send <b>evidence</b> to&nbsp;...
#
#
#
#
#
#
# (2) a party offers in evidence to prove the truth of the matter asserted in the ... is founded upon an unwillingness to countenance the general use of prior ...
#
#
# (2) a party offers in <b>evidence</b> to <b>prove</b> the truth of the matter asserted in the ... is <b>founded</b> upon an unwillingness to countenance the general use of <b>prior</b>&nbsp;...
#
#
#
#
#
#
# May 29, 2020 ... A detailed article about the documents you need to prove that your company exists. This includes what the Articles of Incorporation is and ...
#
#
# May 29, 2020 <b>...</b> A detailed article about the documents you need to <b>prove</b> that your company <b>exists</b>. This includes what the Articles of Incorporation is and&nbsp;...
#
#
#
#
#
#
# An LP must be created and in existence before it can take the additional step of registering as an LLP. Are LLPs exempt from franchise tax? There have been ...
#
#
# An LP must be <b>created</b> and in existence <b>before</b> it can take the additional step of registering as an LLP. Are LLPs exempt from <b>franchise</b> tax? There have been&nbsp;...
#
#
#
#
#
#
# Chuck E. Cheese is an American children's family entertainment center (which also serves pizza) chain founded in 1977 by Atari's co-founder Nolan Bushnell.
#
#
# <b>Chuck E</b>. <b>Cheese</b> is an American children&#39;s family entertainment center (which also serves pizza) chain <b>founded</b> in 1977 by Atari&#39;s co-<b>founder</b> Nolan Bushnell.
#
#
#
#
#
#
# Jun 29, 2020 ... 1977: The Founder ... Nolan Bushnell became successful in the '70s as the co-founder of the video game company Atari, which brought games like ...
#
#
# Jun 29, 2020 <b>...</b> 1977: The <b>Founder</b> ... Nolan Bushnell became successful in the &#39;70s as the co-<b>founder</b> of the video game company Atari, which brought games like&nbsp;...
#
#
#
#
#
#
# Jul 2, 2022 ... Chuck E. Cheese's was founded by Nolan Bushnell in 1977, the same year he sold his company, Atari (makers of Pong) for $28 million.
#
#
# Jul 2, 2022 <b>...</b> <b>Chuck E</b>. <b>Cheese&#39;s</b> was <b>founded</b> by Nolan Bushnell in 1977, the same year he sold his company, Atari (makers of Pong) for $28 million.
#
#
#
#
#
#
# The history of Chuck E. Cheese's begins with Nolan Bushnell. Bushnell grew up in Utah and while earning an electrical engineering degree from the University of ...
#
#
# The history of <b>Chuck E</b>. <b>Cheese&#39;s</b> begins with Nolan Bushnell. Bushnell grew up in Utah and while earning an electrical engineering degree from the University of&nbsp;...
#
#
#
#
#
#
# Sep 9, 2022 ... A complete timeline of Chuck E. Cheese's History from founding to present including key milestones and major events.
#
#
# Sep 9, 2022 <b>...</b> A complete timeline of <b>Chuck E</b>. <b>Cheese&#39;s</b> History from <b>founding</b> to present including key milestones and major events.
#
#
#
#
#
#
# Jun 9, 2017 ... Pasqually set up Charles to be an attraction for his restaurant: a singing mouse. His first performance was a failure, and people started ...
#
#
# Jun 9, 2017 <b>...</b> Pasqually set up Charles to be an attraction for his restaurant: a singing mouse. His first performance was a failure, <b>and</b> people <b>started</b>&nbsp;...
#
#
#
#
#
#
# Jun 25, 2020 ... Cheese was originally created by Atari cofounder Nolan Bushnell to serve as the cigar-chewing mascot at Pizza Time Theatre in 1977. Chuck E.
#
#
# Jun 25, 2020 <b>...</b> <b>Cheese</b> was originally <b>created</b> by Atari cofounder Nolan Bushnell to serve as the cigar-chewing mascot at Pizza Time Theatre in 1977. <b>Chuck E</b>.
#
#
#
#
#
#
# Jun 29, 2012 ... Some FunFacts about Nolan Bushnell, inventor, gamer, and cheese-lover. [optional image description]. Enjoy a year of unlimited access to The ...
#
#
# Jun 29, 2012 <b>...</b> Some FunFacts about Nolan Bushnell, inventor, gamer, <b>and cheese</b>-lover. [optional image description]. Enjoy a year of unlimited access to The&nbsp;...
#
#
#
#
#
#
# Mar 26, 2018 ... Atari & Chuck E. Cheese's: Nolan Bushnell. Facebook; Twitter; Flipboard; Email.
#
#
# Mar 26, 2018 <b>...</b> Atari &amp; <b>Chuck E</b>. <b>Cheese&#39;s</b>: Nolan Bushnell. Facebook; Twitter; Flipboard; Email.
#
#
#
#
#
#
# Before he turned 40, Nolan Bushnell founded two brands that permanently shaped the way Americans amuse themselves: the iconic video game system Atari, and ...
#
#
# Before he turned 40, Nolan Bushnell <b>founded</b> two brands that permanently shaped the way Americans amuse themselves: the iconic video game system Atari, <b>and</b>&nbsp;...
#
#
#
#
#
#
# In 1978, Jet's Pizza® founder Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over. Instead, he signed a lease on ...
#
#
# In 1978, <b>Jet&#39;s Pizza</b>® <b>founder</b> Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over. Instead, he signed a lease on&nbsp;...
#
#
#
#
#
#
# HistoryEdit ... The first Jet's Pizza was opened in 1978 by brothers Eugene and John Jetts in Sterling Heights, Michigan. ... The original location was converted ...
#
#
# <b>History</b>Edit ... The first <b>Jet&#39;s Pizza</b> was opened in 1978 by brothers Eugene and John Jetts in Sterling Heights, Michigan. ... The original location was converted&nbsp;...
#
#
#
#
#
#
# In 1978, Jet's Pizza founder, Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over.
#
#
# In 1978, <b>Jet&#39;s Pizza founder</b>, Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over.
#
#
#
#
#
#
# Jan 26, 2023 ... Jet's Pizza co-founder Eugene Jetts told WXYZ-TV Detroit that all the cheese (they use 8.5 million pounds a year) in their restaurants was ...
#
#
# Jan 26, 2023 <b>...</b> <b>Jet&#39;s Pizza</b> co-<b>founder</b> Eugene Jetts told WXYZ-TV Detroit that all the cheese (they use 8.5 million pounds a year) in their restaurants was&nbsp;...
#
#
#
#
#
#
# In 1978, Jet's Pizza® founder Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over. Instead, he signed a lease on ...
#
#
# In 1978, <b>Jet&#39;s Pizza</b>® <b>founder</b> Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over. Instead, he signed a lease on&nbsp;...
#
#
#
#
#
#
# In 1978, Jet's Pizza® founder Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over. Instead, he signed a lease on ...
#
#
# In 1978, <b>Jet&#39;s Pizza</b>® <b>founder</b> Eugene Jetts was about to buy a new home. But on the way there, his passion for pizza took over. Instead, he signed a lease on&nbsp;...
#
#
#
#
#
#
# Dec 12, 2022 ... The first Jet's Pizza was opened in 1978 by brothers Eugene and John Jetts. Eugene had been set to buy a house but decided to pursue his ...
#
#
# Dec 12, 2022 <b>...</b> The first <b>Jet&#39;s Pizza</b> was opened in 1978 by brothers Eugene and John Jetts. Eugene had been set to buy a house but decided to pursue his&nbsp;...
#
#
#
#
#
#
# Jim Galloway · Vice President Franchise Sales at Jet's Pizza · Report · Report · Experience · Education · Looking for career advice? · Others named Jim Galloway · View ...
#
#
# Jim Galloway &middot; Vice President Franchise Sales at <b>Jet&#39;s Pizza</b> &middot; Report &middot; Report &middot; Experience &middot; Education &middot; Looking for career advice? &middot; Others named Jim Galloway &middot; View&nbsp;...
#
#
#
#
#
#
# Jul 28, 2022 ... Jet's Pizza® is based in Sterling Heights, Michigan. It was founded as Jetts Party Shoppe and Pizzeria in 1978 by brothers, John and Eugene ...
#
#
# Jul 28, 2022 <b>...</b> <b>Jet&#39;s Pizza</b>® is based in Sterling Heights, Michigan. It was <b>founded</b> as Jetts Party Shoppe and Pizzeria in 1978 by brothers, John and Eugene&nbsp;...
#
#
#
#
#
#
# Andrew Trautmann · Owner/Operator at Jet's Pizza- Chicago, IL · Report · Report · Activity · Experience · Education · More activity by Andrew · Looking for career ...
#
#
# Andrew Trautmann &middot; <b>Owner</b>/Operator at <b>Jet&#39;s Pizza</b>- Chicago, IL &middot; Report &middot; Report &middot; Activity &middot; Experience &middot; Education &middot; More activity by Andrew &middot; Looking for career&nbsp;...
#
#
#
#
#
#
# 6 days ago ... Directions to Roden Cutler House (Haymarket) with public transport. The following transport lines have routes that pass near Roden Cutler ...
#
#
# 6 days ago <b>...</b> Directions to <b>Roden Cutler House</b> (Haymarket) with public transport. The following transport lines <b>have</b> routes that pass near <b>Roden Cutler</b>&nbsp;...
#
#
#
#
#
#
# Much loved, still remembered as a man equally at home in the company of royalty or trade unionists. His story is embedded in Australian history, and part of it.
#
#
# Much loved, still remembered as a man equally at <b>home</b> in the <b>company</b> of royalty or trade unionists. His story <b>is</b> embedded in Australian history, and part of it.
#
#
#
#
#
#
# 6 days ago ... Directions to Roden Cutler House (Kirrawee) with public transport. The following transport lines have routes that pass near Roden Cutler ...
#
#
# 6 days ago <b>...</b> Directions to <b>Roden Cutler House</b> (Kirrawee) with public transport. The following transport lines <b>have</b> routes that pass near <b>Roden Cutler</b>&nbsp;...
#
#
#
#
#
#
# He was invalided home and was invested with the Victoria Cross, while standing on crutches, by the Governor General of Australia, Lord Gowrie, on 11 June 1942.
#
#
# He <b>was</b> invalided <b>home</b> and <b>was</b> invested with the Victoria Cross, while standing on crutches, by the Governor General of Australia, Lord Gowrie, on 11 June 1942.
#
#
#
#
#
#
# Dec 16, 2022 ... Sir Arthur Roden Cutler is remembered for his lifelong military, ... [Arthur Roden Cutler, letter home to his mother Ruby, 1941.
#
#
# Dec 16, 2022 <b>...</b> Sir Arthur <b>Roden Cutler is</b> remembered for his lifelong military, ... [Arthur <b>Roden Cutler</b>, letter <b>home</b> to his mother Ruby, 1941.
#
#
#
#
#
#
# Sir Arthur Roden Cutler, VC, AK, KCMG, KCVO, CBE (24 May 1916 – 21 February 2002) was an Australian diplomat, the longest-serving Governor of New South ...
#
#
# Sir Arthur <b>Roden Cutler</b>, VC, AK, KCMG, KCVO, CBE (24 May 1916 – 21 February 2002) <b>was</b> an Australian diplomat, the longest-serving Governor of New South&nbsp;...
#
#
#
#
#
#
# Roden Cutler Lodge is a fully featured, quality Anglicare aged care home ... Both of these properties were purchased by John Woolcott Forbes in 1936 and ...
#
#
# <b>Roden Cutler</b> Lodge <b>is</b> a fully featured, quality Anglicare aged care <b>home</b> ... Both of these properties <b>were purchased</b> by John Woolcott Forbes in 1936 and&nbsp;...
#
#
#
#
#
#
# Colleen McCullough was born in Australia. A neuropathologist, she established the department of neurophysiology at the Royal North Shore Hospital in Sydney ...
#
#
# Colleen McCullough <b>was</b> born in Australia. A neuropathologist, she established the department of neurophysiology at the Royal North Shore Hospital in Sydney&nbsp;...
#
#
#
#
#
#
# Get sold price history for this house & median property prices for Bonner, ... 64 Roden Cutler Drive is a 2 bedroom, 1 bathroom house with 2 carspaces ...
#
#
# <b>Get</b> sold price history for this <b>house</b> &amp; median property prices for Bonner, ... 64 <b>Roden Cutler</b> Drive <b>is</b> a 2 bedroom, 1 bathroom <b>house</b> with 2 carspaces&nbsp;...
#
#
#
#
#
#
# Much loved, still remembered as a man equally at home in the company of royalty or trade unionists.His story is embedded in Australian history, and part of ...
#
#
# Much loved, still remembered as a man equally at <b>home</b> in the <b>company</b> of royalty or trade unionists.His story <b>is</b> embedded in Australian history, and part of&nbsp;...

# %%
print

# %% [markdown]
# the following code wasn't working

# %%
import requests
import json

# Load the JSON file containing questions
with open('/content/tables.json') as f:
    questions = json.load(f)

# Define the API endpoint and parameters
url = 'https://cse.google.com/cse?cx=f048ca8e92d064c34'
params = {
    'q': '',
    'cx': 'f048ca8e92d064c34',
    'key': 'AIzaSyCWJ9-zXoQr53YWxT9hHoGX4DGRsWNx_kQ',
    'num': 1
}

# Iterate over each question and make a request to the API
for q in questions:
    params['q'] = q  # Set the 'q' parameter to the current question
    response = requests.get(url, params=params)  # Make a GET request to the API

    # print(type(response))
    results = response.json()  # Extract the search results from the response
    # Process the search results as needed
    print(results)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/requests/models.py in json(self, **kwargs)
#     909         try:
# --> 910             return complexjson.loads(self.text, **kwargs)
#     911         except JSONDecodeError as e:
#
# /usr/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-15-73ae286d7d0b> in <module>
#      21
#      22     # print(type(response))
# ---> 23     results = response.json()  # Extract the search results from the response
#      24     # Process the search results as needed
#      25     print(results)
#
# /usr/local/lib/python3.9/dist-packages/requests/models.py in json(self, **kwargs)
#     915                 raise RequestsJSONDecodeError(e.message)
#     916             else:
# --> 917                 raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     918
#     919     @property
#
# JSONDecodeError: [Errno Expecting value] <!doctype html><html lang="zh-TW"><head><meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="noindex" name="robots"><link href="https://www.google.com/favicon.ico" rel="icon" type="image/x-icon"><link href="https://fonts.googleapis.com/css?family=Product+Sans" rel="stylesheet" nonce="iL8665Jxqna76OBK8HNgIA"><title>Programmable Search Engine</title><script nonce="iL8665Jxqna76OBK8HNgIA">(function(){var relativeUrl='/cse.js?num\x3d1\x26ie\x3dUTF-8\x26hpg\x3d1\x26cx\x3df048ca8e92d064c34';(function(){var gcse = document.createElement('script');gcse.type = 'text/javascript';gcse.async = true;gcse.src = relativeUrl;var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(gcse,s);})();})();</script><style>body{background-color:#FFFFFF;color:#333333;font-family:arial,sans-serif}.gs-webResult{padding:2px 0;width:42em}.gsc-results .gsc-cursor-box{text-align:center}#cse-search-form{padding:0 20px;width:22em}#cse-header{display:-ms-flexbox;display:flex;-ms-flex-align:end;align-items:flex-end;padding:10px 4px}#cse-footer{clear:both;font-size:82%;text-align:center;padding:16px}#DZPTFe{display:none}</style></head><body><noscript><h3>Programmable Search Engine requires JavaScript</h3><p>JavaScript is either disabled or not supported by your browser. To use Programmable Search Engine, enable JavaScript by changing your browser options and reloading this page.</p></noscript><div id="cse-host...
